# %% [markdown]
# # Setup

# %%
import pandas as pd
import random

# Load dataset
df = pd.read_csv("03_cleaned_with_images_and_evolutionary_stages.csv")  # your CSV

# %%
ATTRIBUTES = ['Generation', 'Height', 'Weight', 'Type1', 'Type2', 'Color', 'evolutionary_stage']

# %% [markdown]
# # Solver Core functionality

# %%
def get_feedback(secret, guess):
    feedback = {}
    for attr in ATTRIBUTES:
        if pd.isna(secret[attr]) or pd.isna(guess[attr]):
            feedback[attr] = 'gray'
        elif secret[attr] == guess[attr]:
            feedback[attr] = 'green'
        else:
            feedback[attr] = 'gray'
    return feedback

# %%
class PokedleCSP:
    def __init__(self, dataframe, attributes=ATTRIBUTES):
        self.df = dataframe.copy()
        self.attributes = attributes
        self.constraints = {col: [] for col in self.attributes}

    def apply_feedback(self, guess, feedback):
        """Update constraints based on the feedback."""
        for attr, status in feedback.items():
            value = guess[attr]
            if status == "green":
                self.constraints[attr].append(("==", value))
            elif status == "gray":
                self.constraints[attr].append(("!=", value))
            elif status == "yellow":
                # if we later support partial match (like correct type but wrong position)
                self.constraints[attr].append(("in", value))

    def filter_candidates(self):
        """Filter dataset according to constraints."""
        candidates = self.df
        for attr, conds in self.constraints.items():
            for op, val in conds:
                if op == "==":
                    candidates = candidates[candidates[attr] == val]
                elif op == "!=":
                    candidates = candidates[candidates[attr] != val]
                elif op == "in":
                    candidates = candidates[candidates[attr].apply(lambda x: val in str(x))]
        return candidates

    def next_guess(self, candidates):
        """Heuristic: choose Pokémon with most common attributes among remaining candidates."""
        if len(candidates) == 0:
            return None
        return candidates.sample(1).iloc[0]

# %% [markdown]
# # Runner

# %%
l = []

# %%
def solve(l, attributes=ATTRIBUTES, max_attempts=10):
    solver = PokedleCSP(df, attributes)
    secret = df.sample(1).iloc[0]
    print(f"(DEBUG) Secret Pokémon: {secret['Original_Name']}")

    candidates = df

    for attempt in range(1, max_attempts + 1):
        guess = solver.next_guess(candidates)
        if (len(candidates) == 1):
            print(f"🎯 Guessed correctly! The Pokémon was {guess['Original_Name']}.")
            l.append(attempt)
            break
        if guess is None:
            print(f"💀 No candidates left. Secret was: {secret}")
            l.append(attempt)
            break
        
        feedback = get_feedback(secret, guess)
        print(f"\nAttempt {attempt}: {guess['Original_Name']}")
        print("Feedback:", feedback)
        if all(v == 'green' for v in feedback.values()):
            print(f"🎯 Guessed correctly! The Pokémon was {guess['Original_Name']}.")
            l.append(attempt)
            break
        
        solver.apply_feedback(guess, feedback)
        candidates = solver.filter_candidates()
        print(f"Remaining candidates: {len(candidates)}")

# %%
benchmarks = {}
for i in range(1000):
    solve()
# Out:
# (DEBUG) Secret Pokémon: Carbink
#
# Attempt 1: Aurorus
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 4
#
# Attempt 2: Diancie
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Carbink.
# (DEBUG) Secret Pokémon: Poipole
#
# Attempt 1: Stonjourner
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 399
#
# Attempt 2: Girafarig
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 249
#
# Attempt 3: Regice
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 161
#
# Attempt 4: Comfey
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 22
#
# Attempt 5: Bounsweet
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 6: Tapu Fini
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 7: Crabrawler
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Poipole.
# (DEBUG) Secret Pokémon: Floatzel
#
# Attempt 1: Paras
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 318
#
# Attempt 2: Pawmot
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 177
#
# Attempt 3: Sylveon
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 132
#
# Attempt 4: Dusclops
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 95
#
# Attempt 5: Barraskewda
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Floatzel.
# (DEBUG) Secret Pokémon: Ceruledge
#
# Attempt 1: Dusknoir
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 737
#
# Attempt 2: Fomantis
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 231
#
# Attempt 3: Accelgor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 140
#
# Attempt 4: Bellibolt
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 14
#
# Attempt 5: Ceruledge
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Ceruledge.
# (DEBUG) Secret Pokémon: Gloom
#
# Attempt 1: Misdreavus
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 353
#
# Attempt 2: Staraptor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 149
#
# Attempt 3: Armarouge
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 101
#
# Attempt 4: Corvisquire
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 5: Nidorina
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Gloom.
# (DEBUG) Secret Pokémon: Growlithe
#
# Attempt 1: Metapod
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Growlithe.
# (DEBUG) Secret Pokémon: Blacephalon
#
# Attempt 1: Pichu
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 361
#
# Attempt 2: Kangaskhan
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 237
#
# Attempt 3: Purrloin
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 132
#
# Attempt 4: Regidrago
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 91
#
# Attempt 5: Wingull
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 6: Snover
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 8
#
# Attempt 7: Iron Valiant
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 8: Nihilego
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 9: Passimian
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Blacephalon.
# (DEBUG) Secret Pokémon: Oricorio
#
# Attempt 1: Cetoddle
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 408
#
# Attempt 2: Shellder
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 234
#
# Attempt 3: Bouffalant
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 135
#
# Attempt 4: Darkrai
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 95
#
# Attempt 5: Nosepass
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 51
#
# Attempt 6: Chikorita
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 23
#
# Attempt 7: Arctozolt
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 8
#
# Attempt 8: Spritzee
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 9: Turtonator
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 10: Litten
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# (DEBUG) Secret Pokémon: Drilbur
#
# Attempt 1: Arctozolt
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 378
#
# Attempt 2: Bronzor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 241
#
# Attempt 3: Hoothoot
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 130
#
# Attempt 4: Passimian
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 79
#
# Attempt 5: Munna
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 14
#
# Attempt 6: Joltik
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 7: Heatmor
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 8: Purrloin
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 9: Terrakion
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Drilbur.
# (DEBUG) Secret Pokémon: Kricketune
#
# Attempt 1: Elgyem
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 309
#
# Attempt 2: Medicham
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 18
#
# Attempt 3: Porygon2
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 12
#
# Attempt 4: Torracat
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 5: Kricketune
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Kricketune.
# (DEBUG) Secret Pokémon: Kakuna
#
# Attempt 1: Hippopotas
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 327
#
# Attempt 2: Pupitar
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 162
#
# Attempt 3: Simipour
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 80
#
# Attempt 4: Torracat
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 57
#
# Attempt 5: Cetitan
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 36
#
# Attempt 6: Manectric
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 7: Exeggutor
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 8: Kakuna
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Kakuna.
# (DEBUG) Secret Pokémon: Azumarill
#
# Attempt 1: Seviper
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 382
#
# Attempt 2: Vanilluxe
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 68
#
# Attempt 3: Electivire
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 46
#
# Attempt 4: Garganacl
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 30
#
# Attempt 5: Bellossom
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 6: Azumarill
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Azumarill.
# (DEBUG) Secret Pokémon: Baxcalibur
#
# Attempt 1: Centiskorch
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 508
#
# Attempt 2: Kyogre
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 58
#
# Attempt 3: Meganium
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 39
#
# Attempt 4: Klinklang
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 6
#
# Attempt 5: Machamp
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 6: Rhyperior
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Baxcalibur.
# (DEBUG) Secret Pokémon: Minior
#
# Attempt 1: Mudsdale
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'gray'}
# Remaining candidates: 6
#
# Attempt 2: Rowlet
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Minior.
# (DEBUG) Secret Pokémon: Cetitan
#
# Attempt 1: Corphish
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 305
#
# Attempt 2: Golurk
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 151
#
# Attempt 3: Hitmonlee
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 79
#
# Attempt 4: Gabite
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 44
#
# Attempt 5: Floette
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 7
#
# Attempt 6: Cetitan
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Cetitan.
# (DEBUG) Secret Pokémon: Gigalith
#
# Attempt 1: Shelgon
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 480
#
# Attempt 2: Guzzlord
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 74
#
# Attempt 3: Azumarill
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 4: Gigalith
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Gigalith.
# (DEBUG) Secret Pokémon: Galvantula
#
# Attempt 1: Crocalor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 253
#
# Attempt 2: Slurpuff
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 18
#
# Attempt 3: Flaaffy
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 14
#
# Attempt 4: Palpitoad
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Galvantula
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Galvantula.
# (DEBUG) Secret Pokémon: Staryu
#
# Attempt 1: Manaphy
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 30
#
# Attempt 2: Remoraid
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 17
#
# Attempt 3: Alomomola
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 4: Psyduck
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Staryu.
# (DEBUG) Secret Pokémon: Zebstrika
#
# Attempt 1: Snorunt
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 348
#
# Attempt 2: Blissey
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 185
#
# Attempt 3: Dachsbun
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 131
#
# Attempt 4: Honchkrow
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 5: Salazzle
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 6: Spewpa
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Zebstrika.
# (DEBUG) Secret Pokémon: Poochyena
#
# Attempt 1: Incineroar
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 678
#
# Attempt 2: Dubwool
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 273
#
# Attempt 3: Unown
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 31
#
# Attempt 4: Shinx
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 16
#
# Attempt 5: Mankey
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 7
#
# Attempt 6: Lotad
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 7: Nincada
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Poochyena.
# (DEBUG) Secret Pokémon: Kabutops
#
# Attempt 1: Jirachi
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 358
#
# Attempt 2: Fearow
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 9
#
# Attempt 3: Hitmonlee
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 6
#
# Attempt 4: Dugtrio
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 5: Graveler
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Kabutops.
# (DEBUG) Secret Pokémon: Arctovish
#
# Attempt 1: Magcargo
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 488
#
# Attempt 2: Flamigo
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 309
#
# Attempt 3: Cacnea
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 173
#
# Attempt 4: Bergmite
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 24
#
# Attempt 5: Tympole
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 6
#
# Attempt 6: Tentacool
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 7: Arctovish
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Arctovish.
# (DEBUG) Secret Pokémon: Chewtle
#
# Attempt 1: Chewtle
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Chewtle.
# (DEBUG) Secret Pokémon: Shiinotic
#
# Attempt 1: Quilladin
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 12
#
# Attempt 2: Exeggutor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 8
#
# Attempt 3: Cherrim
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Shiinotic.
# (DEBUG) Secret Pokémon: Bronzor
#
# Attempt 1: Steelix
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 12
#
# Attempt 2: Bronzor
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Bronzor.
# (DEBUG) Secret Pokémon: Skeledirge
#
# Attempt 1: Tinkaton
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 8
#
# Attempt 2: Baxcalibur
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 6
#
# Attempt 3: Skeledirge
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Skeledirge.
# (DEBUG) Secret Pokémon: Oricorio
#
# Attempt 1: Audino
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 361
#
# Attempt 2: Wailmer
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 222
#
# Attempt 3: Klawf
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 19
#
# Attempt 4: Buzzwole
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 5: Tapu Bulu
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 6: Litten
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Oricorio.
# (DEBUG) Secret Pokémon: Salamence
#
# Attempt 1: Morpeko
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 365
#
# Attempt 2: Whirlipede
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 55
#
# Attempt 3: Chesnaught
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 32
#
# Attempt 4: Wigglytuff
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 15
#
# Attempt 5: Feraligatr
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 6: Salamence
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Salamence.
# (DEBUG) Secret Pokémon: Zoroark
#
# Attempt 1: Talonflame
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 610
#
# Attempt 2: Beheeyem
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 26
#
# Attempt 3: Servine
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 16
#
# Attempt 4: Vanillish
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 11
#
# Attempt 5: Zoroark
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Zoroark.
# (DEBUG) Secret Pokémon: Vespiquen
#
# Attempt 1: Tranquill
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 16
#
# Attempt 2: Altaria
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 11
#
# Attempt 3: Honchkrow
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 4: Gliscor
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Yanmega
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Vespiquen.
# (DEBUG) Secret Pokémon: Lokix
#
# Attempt 1: Starmie
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 204
#
# Attempt 2: Ninjask
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 14
#
# Attempt 3: Golisopod
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 4: Escavalier
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Lokix.
# (DEBUG) Secret Pokémon: Snorlax
#
# Attempt 1: Deoxys
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 341
#
# Attempt 2: Forretress
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 166
#
# Attempt 3: Hitmonlee
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 24
#
# Attempt 4: Wartortle
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 5: Ninetales
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 6: Snorlax
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Snorlax.
# (DEBUG) Secret Pokémon: Tadbulb
#
# Attempt 1: Bewear
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 467
#
# Attempt 2: Rotom
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 7
#
# Attempt 3: Yamper
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 4: Tadbulb
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Tadbulb.
# (DEBUG) Secret Pokémon: Tirtouga
#
# Attempt 1: Boltund
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 497
#
# Attempt 2: Necrozma
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 319
#
# Attempt 3: Piplup
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 20
#
# Attempt 4: Quaxly
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 5: Poliwag
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 6: Froakie
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 7: Tirtouga
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Tirtouga.
# (DEBUG) Secret Pokémon: Haunter
#
# Attempt 1: Kakuna
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 2: Tentacruel
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Haunter.
# (DEBUG) Secret Pokémon: Brute Bonnet
#
# Attempt 1: Honchkrow
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 470
#
# Attempt 2: Clefable
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 289
#
# Attempt 3: Quaxly
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 33
#
# Attempt 4: Bramblin
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 5: Smoliv
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Brute Bonnet.
# (DEBUG) Secret Pokémon: Espathra
#
# Attempt 1: Crobat
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 637
#
# Attempt 2: Whiscash
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 160
#
# Attempt 3: Toedscruel
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Espathra.
# (DEBUG) Secret Pokémon: Slurpuff
#
# Attempt 1: Plusle
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 369
#
# Attempt 2: Pignite
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 175
#
# Attempt 3: Revavroom
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 125
#
# Attempt 4: Quagsire
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 72
#
# Attempt 5: Nidorino
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 39
#
# Attempt 6: Trevenant
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 6
#
# Attempt 7: Aromatisse
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Slurpuff.
# (DEBUG) Secret Pokémon: Jangmo-o
#
# Attempt 1: Diglett
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 372
#
# Attempt 2: Torchic
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 236
#
# Attempt 3: Corsola
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 18
#
# Attempt 4: Squawkabilly
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 9
#
# Attempt 5: Jangmo-o
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Jangmo-o.
# (DEBUG) Secret Pokémon: Dragapult
#
# Attempt 1: Phanpy
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 327
#
# Attempt 2: Tsareena
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 47
#
# Attempt 3: Porygon-Z
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 29
#
# Attempt 4: Alakazam
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 14
#
# Attempt 5: Tinkaton
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 6: Haxorus
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Dragapult.
# (DEBUG) Secret Pokémon: Togepi
#
# Attempt 1: Skrelp
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 366
#
# Attempt 2: Snom
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 3: Kartana
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 4: Tandemaus
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Togepi
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Togepi.
# (DEBUG) Secret Pokémon: Skiddo
#
# Attempt 1: Cyndaquil
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 365
#
# Attempt 2: Oranguru
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 231
#
# Attempt 3: Horsea
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 114
#
# Attempt 4: Goomy
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 8
#
# Attempt 5: Skiddo
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Skiddo.
# (DEBUG) Secret Pokémon: Cutiefly
#
# Attempt 1: Gogoat
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 468
#
# Attempt 2: Lechonk
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 237
#
# Attempt 3: Comfey
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Cutiefly.
# (DEBUG) Secret Pokémon: Elekid
#
# Attempt 1: Ambipom
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 455
#
# Attempt 2: Elekid
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Elekid.
# (DEBUG) Secret Pokémon: Totodile
#
# Attempt 1: Exeggutor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 432
#
# Attempt 2: Salandit
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 38
#
# Attempt 3: Wooloo
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 24
#
# Attempt 4: Remoraid
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Totodile
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Totodile.
# (DEBUG) Secret Pokémon: Enamorus
#
# Attempt 1: Mantine
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 48
#
# Attempt 2: Wattrel
# ...
# 🎯 Guessed correctly! The Pokémon was Grapploct.
# (DEBUG) Secret Pokémon: Gible
#
# Attempt 1: Bronzor
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 37
#
# Attempt 2: Combee
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 24
#
# Attempt 3: Spiritomb
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 18
#
# Attempt 4: Riolu
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Gible
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Gible.
# (DEBUG) Secret Pokémon: Drilbur
#
# Attempt 1: Drednaw
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 428
#
# Attempt 2: Zeraora
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 256
#
# Attempt 3: Seviper
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 188
#
# Attempt 4: Delibird
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 116
#
# Attempt 5: Xerneas
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 76
#
# Attempt 6: Eevee
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 7
#
# Attempt 7: Klink
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 8: Drilbur
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Drilbur.
# (DEBUG) Secret Pokémon: Illumise
#
# Attempt 1: Skiploom
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 42
#
# Attempt 2: Whismur
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 9
#
# Attempt 3: Shuppet
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 7
#
# Attempt 4: Wynaut
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 5: Feebas
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Illumise.
# (DEBUG) Secret Pokémon: Hoppip
#
# Attempt 1: Sandygast
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 341
#
# Attempt 2: Heatmor
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 238
#
# Attempt 3: Iron Jugulis
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 15
#
# Attempt 4: Gligar
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 5: Skarmory
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 6: Lugia
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Hoppip.
# (DEBUG) Secret Pokémon: Palkia
#
# Attempt 1: Victreebel
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 602
#
# Attempt 2: Klefki
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 270
#
# Attempt 3: Sandygast
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 173
#
# Attempt 4: Makuhita
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 110
#
# Attempt 5: Heracross
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 53
#
# Attempt 6: Tinkatink
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 26
#
# Attempt 7: Glastrier
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 12
#
# Attempt 8: Munchlax
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 4
#
# Attempt 9: Rotom
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 10: Skorupi
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# (DEBUG) Secret Pokémon: Jangmo-o
#
# Attempt 1: Tropius
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 336
#
# Attempt 2: Flutter Mane
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 29
#
# Attempt 3: Kyurem
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Jangmo-o.
# (DEBUG) Secret Pokémon: Litleo
#
# Attempt 1: Tinkaton
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 673
#
# Attempt 2: Cacnea
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 240
#
# Attempt 3: Palkia
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 156
#
# Attempt 4: Zekrom
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 103
#
# Attempt 5: Farfetch'd
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 6: Rockruff
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 7: Clobbopus
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Litleo.
# (DEBUG) Secret Pokémon: Gardevoir
#
# Attempt 1: Hoopa
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 20
#
# Attempt 2: Hypno
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 2
#
# Attempt 3: Gallade
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Gardevoir.
# (DEBUG) Secret Pokémon: Beedrill
#
# Attempt 1: Entei
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 335
#
# Attempt 2: Musharna
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 55
#
# Attempt 3: Kommo-o
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 36
#
# Attempt 4: Vileplume
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 5: Beedrill
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Beedrill.
# (DEBUG) Secret Pokémon: Krokorok
#
# Attempt 1: Cacturne
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 5
#
# Attempt 2: Skuntank
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 2
#
# Attempt 3: Krokorok
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Krokorok.
# (DEBUG) Secret Pokémon: Chandelure
#
# Attempt 1: Cradily
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 431
#
# Attempt 2: Vivillon
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 45
#
# Attempt 3: Nidoking
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 30
#
# Attempt 4: Pawmot
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 17
#
# Attempt 5: Azumarill
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 9
#
# Attempt 6: Obstagoon
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 3
#
# Attempt 7: Chandelure
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# 🎯 Guessed correctly! The Pokémon was Chandelure.
# (DEBUG) Secret Pokémon: Latios
#
# Attempt 1: Gloom
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'gray'}
# Remaining candidates: 87
#
# Attempt 2: Karrablast
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 46
#
# Attempt 3: Amaura
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 36
#
# Attempt 4: Meditite
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'green', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Latios.
# (DEBUG) Secret Pokémon: Blissey
#
# Attempt 1: Torterra
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 76
#
# Attempt 2: Grimmsnarl
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 10
#
# Attempt 3: Blissey
# Feedback: {'Generation': 'green', 'Height': 'green', 'Weight': 'green', 'Type1': 'green', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Blissey.
# (DEBUG) Secret Pokémon: Pelipper
#
# Attempt 1: Wingull
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'green', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Pelipper.
# (DEBUG) Secret Pokémon: Iron Moth
#
# Attempt 1: Monferno
# Feedback: {'Generation': 'gray', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 30
#
# Attempt 2: Charcadet
# Feedback: {'Generation': 'green', 'Height': 'gray', 'Weight': 'gray', 'Type1': 'green', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Iron Moth.
# (DEBUG) Secret Pokémon: Dusclops
#
# Attempt 1: Magmortar
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 19
#
# Attempt 2: Iron Thorns
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'gray', 'evolutionary_stage': 'gray'}
# Remaining candidates: 13
#
# Attempt 3: Zebstrika
# Feedback: {'Generation': 'gray', 'Height': 'green', 'Weight': 'gray', 'Type1': 'gray', 'Type2': 'gray', 'Color': 'green', 'evolutionary_stage': 'green'}
# Remaining candidates: 1
# 🎯 Guessed correctly! The Pokémon was Dusclops.

# %% [markdown]
# # Benchmarks
# - Took 0.0408 seconds per run for CSP with heuristic choose Pokémon with most common attributes among remaining candidates.
# - about 6.581892917369308 attempts on an average

# %%
a = sum(l)/len(l)

# %%
a
# Out:
# 5.889

# %%
len(ATTRIBUTES)
# Out:
# 7
